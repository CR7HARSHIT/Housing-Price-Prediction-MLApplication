# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
#FOR inline display of graph and visualization

# %%
#Let's load the Ames house pricing dataset
Ames_dataset=pd.read_csv("AmesHousing.csv")

# %%
#In an dataset there we be one output/dependent feature and rest will be independent feature
Ames_dataset
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2      NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3      NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4      NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2925   NaN       IR1          Lvl  ...         0     NaN  GdPrv          NaN
# 2926   NaN       IR1          Low  ...         0     NaN  MnPrv          NaN
# 2927   NaN       Reg          Lvl  ...         0     NaN  MnPrv         Shed
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# 2       12500       6    2010       WD           Normal     172000
# 3           0       4    2010       WD           Normal     244000
# 4           0       3    2010       WD           Normal     189900
# ...       ...     ...     ...       ...             ...        ...
# 2925        0       3    2006       WD           Normal     142500
# 2926        0       6    2006       WD           Normal     131000
# 2927      700       7    2006       WD           Normal     132000
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %%
Ames_dataset.keys()
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'Sale Condition', 'SalePrice'],
#       dtype='object')

# %%
Ames_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
#  16  Bldg Type        2930 non-null   object
#  17  House Style      2930 non-null   object
#  18  Overall Qual     2930 non-null   int64
#  19  Overall Cond     2930 non-null   int64
#  20  Year Built       2930 non-null   int64
#  21  Year Remod/Add   2930 non-null   int64
#  22  Roof Style       2930 non-null   object
#  23  Roof Matl        2930 non-null   object
#  24  Exterior 1st     2930 non-null   object
#  25  Exterior 2nd     2930 non-null   object
#  26  Mas Vnr Type     1155 non-null   object
#  27  Mas Vnr Area     2907 non-null   float64
#  28  Exter Qual       2930 non-null   object
#  29  Exter Cond       2930 non-null   object
#  30  Foundation       2930 non-null   object
#  31  Bsmt Qual        2850 non-null   object
#  32  Bsmt Cond        2850 non-null   object
#  33  Bsmt Exposure    2847 non-null   object
#  34  BsmtFin Type 1   2850 non-null   object
#  35  BsmtFin SF 1     2929 non-null   float64
#  36  BsmtFin Type 2   2849 non-null   object
#  37  BsmtFin SF 2     2929 non-null   float64
#  38  Bsmt Unf SF      2929 non-null   float64
#  39  Total Bsmt SF    2929 non-null   float64
#  40  Heating          2930 non-null   object
#  41  Heating QC       2930 non-null   object
#  42  Central Air      2930 non-null   object
#  43  Electrical       2929 non-null   object
#  44  1st Flr SF       2930 non-null   int64
#  45  2nd Flr SF       2930 non-null   int64
#  46  Low Qual Fin SF  2930 non-null   int64
#  47  Gr Liv Area      2930 non-null   int64
#  48  Bsmt Full Bath   2928 non-null   float64
#  49  Bsmt Half Bath   2928 non-null   float64
#  50  Full Bath        2930 non-null   int64
#  51  Half Bath        2930 non-null   int64
#  52  Bedroom AbvGr    2930 non-null   int64
#  53  Kitchen AbvGr    2930 non-null   int64
#  54  Kitchen Qual     2930 non-null   object
#  55  TotRms AbvGrd    2930 non-null   int64
#  56  Functional       2930 non-null   object
#  57  Fireplaces       2930 non-null   int64
#  58  Fireplace Qu     1508 non-null   object
#  59  Garage Type      2773 non-null   object
#  60  Garage Yr Blt    2771 non-null   float64
#  61  Garage Finish    2771 non-null   object
#  62  Garage Cars      2929 non-null   float64
#  63  Garage Area      2929 non-null   float64
#  64  Garage Qual      2771 non-null   object
#  65  Garage Cond      2771 non-null   object
#  66  Paved Drive      2930 non-null   object
#  67  Wood Deck SF     2930 non-null   int64
#  68  Open Porch SF    2930 non-null   int64
#  69  Enclosed Porch   2930 non-null   int64
#  70  3Ssn Porch       2930 non-null   int64
#  71  Screen Porch     2930 non-null   int64
#  72  Pool Area        2930 non-null   int64
#  73  Pool QC          13 non-null     object
#  74  Fence            572 non-null    object
#  75  Misc Feature     106 non-null    object
#  76  Misc Val         2930 non-null   int64
#  77  Mo Sold          2930 non-null   int64
#  78  Yr Sold          2930 non-null   int64
#  79  Sale Type        2930 non-null   object
#  80  Sale Condition   2930 non-null   object
#  81  SalePrice        2930 non-null   int64
# dtypes: float64(11), int64(28), object(43)
# memory usage: 1.8+ MB

# %%
Ames_dataset.head(50)
# Out:
#     Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0       1  526301100           20        RL         141.0     31770   Pave
# 1       2  526350040           20        RH          80.0     11622   Pave
# 2       3  526351010           20        RL          81.0     14267   Pave
# 3       4  526353030           20        RL          93.0     11160   Pave
# 4       5  527105010           60        RL          74.0     13830   Pave
# 5       6  527105030           60        RL          78.0      9978   Pave
# 6       7  527127150          120        RL          41.0      4920   Pave
# 7       8  527145080          120        RL          43.0      5005   Pave
# 8       9  527146030          120        RL          39.0      5389   Pave
# 9      10  527162130           60        RL          60.0      7500   Pave
# 10     11  527163010           60        RL          75.0     10000   Pave
# 11     12  527165230           20        RL           NaN      7980   Pave
# 12     13  527166040           60        RL          63.0      8402   Pave
# 13     14  527180040           20        RL          85.0     10176   Pave
# 14     15  527182190          120        RL           NaN      6820   Pave
# 15     16  527216070           60        RL          47.0     53504   Pave
# 16     17  527225035           50        RL         152.0     12134   Pave
# 17     18  527258010           20        RL          88.0     11394   Pave
# 18     19  527276150           20        RL         140.0     19138   Pave
# 19     20  527302110           20        RL          85.0     13175   Pave
# 20     21  527358140           20        RL         105.0     11751   Pave
# 21     22  527358200           85        RL          85.0     10625   Pave
# 22     23  527368020           60        FV           NaN      7500   Pave
# 23     24  527402200           20        RL           NaN     11241   Pave
# 24     25  527402250           20        RL           NaN     12537   Pave
# 25     26  527403020           20        RL          65.0      8450   Pave
# 26     27  527404120           20        RL          70.0      8400   Pave
# 27     28  527425090           20        RL          70.0     10500   Pave
# 28     29  527427230          120        RH          26.0      5858   Pave
# 29     30  527451180          160        RM          21.0      1680   Pave
# 30     31  527451330          160        RM          21.0      1680   Pave
# 31     32  527451410          160        RM          21.0      1680   Pave
# 32     33  527452190          120        RL          53.0      4043   Pave
# 33     34  527453130          160        RL          24.0      2280   Pave
# 34     35  527453150          120        RL          24.0      2280   Pave
# 35     36  527454200          160        RL          24.0      2280   Pave
# 36     37  528108120           60        RL         102.0     12858   Pave
# 37     38  528112020           20        RL          98.0     11478   Pave
# 38     39  528120060           20        RL          83.0     10159   Pave
# 39     40  528120090           20        RL          94.0     12883   Pave
# 40     41  528120100           20        RL          95.0     12182   Pave
# 41     42  528120120           20        RL          90.0     11520   Pave
# 42     43  528138020           20        RL          79.0     14122   Pave
# 43     44  528138060           20        RL          70.0     10171   Pave
# 44     45  528150070           20        RL         100.0     12919   Pave
# 45     46  528175010          120        RL          44.0      6371   Pave
# 46     47  528176010           20        RL         110.0     14300   Pave
# 47     48  528176070           60        RL         105.0     13650   Pave
# 48     49  528180070          120        RL          61.0      7658   Pave
# 49     50  528181050          120        RL          41.0      7132   Pave
#
#    Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0    NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1    NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2    NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3    NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4    NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# 5    NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 6    NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 7    NaN       IR1          HLS  ...         0     NaN    NaN          NaN
# 8    NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 9    NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 10   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 11   NaN       IR1          Lvl  ...         0     NaN  GdPrv         Shed
# 12   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 13   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 14   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 15   NaN       IR2          HLS  ...         0     NaN    NaN          NaN
# 16   NaN       IR1          Bnk  ...         0     NaN    NaN          NaN
# 17   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 18   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 19   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 20   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# 21   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 22   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 23   NaN       IR1          Lvl  ...         0     NaN    NaN         Shed
# 24   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 25   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 26   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 27   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 28   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 29   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 30   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 31   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 32   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 33   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 34   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 35   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 36   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 37   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 38   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 39   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 40   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 41   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 42   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 43   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 44   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 45   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 46   NaN       Reg          HLS  ...         0     NaN    NaN          NaN
# 47   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 48   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 49   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
#
#    Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0         0       5    2010       WD           Normal     215000
# 1         0       6    2010       WD           Normal     105000
# 2     12500       6    2010       WD           Normal     172000
# 3         0       4    2010       WD           Normal     244000
# 4         0       3    2010       WD           Normal     189900
# 5         0       6    2010       WD           Normal     195500
# 6         0       4    2010       WD           Normal     213500
# 7         0       1    2010       WD           Normal     191500
# 8         0       3    2010       WD           Normal     236500
# 9         0       6    2010       WD           Normal     189000
# 10        0       4    2010       WD           Normal     175900
# 11      500       3    2010       WD           Normal     185000
# 12        0       5    2010       WD           Normal     180400
# 13        0       2    2010       WD           Normal     171500
# 14        0       6    2010       WD           Normal     212000
# 15        0       6    2010       WD           Normal     538000
# 16        0       6    2010       WD           Normal     164000
# 17        0       6    2010       New         Partial     394432
# 18        0       6    2010       WD           Normal     141000
# 19        0       2    2010       WD           Normal     210000
# 20        0       1    2010       COD          Normal     190000
# 21        0       1    2010       WD           Family     170000
# 22        0       1    2010       WD           Normal     216000
# 23      700       3    2010       WD           Normal     149000
# 24        0       4    2010       WD           Normal     149900
# 25        0       7    2010       WD           Normal     142000
# 26        0       4    2010       WD           Normal     126000
# 27        0       4    2010     ConLI          Normal     115000
# 28        0       6    2010       WD           Normal     184000
# 29        0       2    2010       COD          Normal      96000
# 30        0       3    2010       WD           Normal     105500
# 31        0       3    2010       WD           Family      88000
# 32        0       7    2010       WD           Normal     127500
# 33        0       6    2010       WD           Normal     149900
# 34        0       6    2010       WD           Normal     120000
# 35        0       7    2010       WD           Normal     146000
# 36        0       1    2010       New         Partial     376162
# 37        0       5    2010       WD           Normal     306000
# 38        0       4    2010       New         Partial     395192
# 39        0       6    2010       New         Partial     290941
# 40        0       5    2010       New         Partial     220000
# 41        0       6    2010       WD           Normal     275000
# 42        0       2    2010       WD           Normal     259000
# 43        0       3    2010       WD           Normal     214000
# 44        0       3    2010       New         Partial     611657
# 45        0       6    2010       New         Partial     224000
# 46        0       6    2010       WD           Normal     500000
# 47        0       6    2010       WD           Normal     320000
# 48        0       2    2010       WD           Normal     319900
# 49        0       4    2010       WD           Normal     205000
#
# [50 rows x 82 columns]

# %%
#Summarizing the stats of data
Ames_dataset.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# std        1.411026      1.111537    30.245361       20.860286    179.112611
# min        1.000000      1.000000  1872.000000     1950.000000      0.000000
# 25%        5.000000      5.000000  1954.000000     1965.000000      0.000000
# 50%        6.000000      5.000000  1973.000000     1993.000000      0.000000
# 75%        7.000000      6.000000  2001.000000     2004.000000    164.000000
# max       10.000000      9.000000  2010.000000     2010.000000   1600.000000
#
#        ...  Wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  \
# count  ...   2930.000000    2930.000000     2930.000000  2930.000000
# mean   ...     93.751877      47.533447       23.011604     2.592491
# std    ...    126.361562      67.483400       64.139059    25.141331
# min    ...      0.000000       0.000000        0.000000     0.000000
# 25%    ...      0.000000       0.000000        0.000000     0.000000
# 50%    ...      0.000000      27.000000        0.000000     0.000000
# 75%    ...    168.000000      70.000000        0.000000     0.000000
# max    ...   1424.000000     742.000000     1012.000000   508.000000
#
#        Screen Porch    Pool Area      Misc Val      Mo Sold      Yr Sold  \
# count   2930.000000  2930.000000   2930.000000  2930.000000  2930.000000
# mean      16.002048     2.243345     50.635154     6.216041  2007.790444
# std       56.087370    35.597181    566.344288     2.714492     1.316613
# min        0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%        0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%        0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%        0.000000     0.000000      0.000000     8.000000  2009.000000
# max      576.000000   800.000000  17000.000000    12.000000  2010.000000
#
#            SalePrice
# count    2930.000000
# mean   180796.060068
# std     79886.692357
# min     12789.000000
# 25%    129500.000000
# 50%    160000.000000
# 75%    213500.000000
# max    755000.000000
#
# [8 rows x 39 columns]

# %%
#CHECK THE MISSING VALUES
Ames_dataset.isnull()
# Out:
#       Order    PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  \
# 0     False  False        False      False         False     False   False
# 1     False  False        False      False         False     False   False
# 2     False  False        False      False         False     False   False
# 3     False  False        False      False         False     False   False
# 4     False  False        False      False         False     False   False
# ...     ...    ...          ...        ...           ...       ...     ...
# 2925  False  False        False      False         False     False   False
# 2926  False  False        False      False          True     False   False
# 2927  False  False        False      False         False     False   False
# 2928  False  False        False      False         False     False   False
# 2929  False  False        False      False         False     False   False
#
#       Alley  Lot Shape  Land Contour  ...  Pool Area  Pool QC  Fence  \
# 0      True      False         False  ...      False     True   True
# 1      True      False         False  ...      False     True  False
# 2      True      False         False  ...      False     True   True
# 3      True      False         False  ...      False     True   True
# 4      True      False         False  ...      False     True  False
# ...     ...        ...           ...  ...        ...      ...    ...
# 2925   True      False         False  ...      False     True  False
# 2926   True      False         False  ...      False     True  False
# 2927   True      False         False  ...      False     True  False
# 2928   True      False         False  ...      False     True   True
# 2929   True      False         False  ...      False     True   True
#
#       Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 0             True     False    False    False      False           False
# 1             True     False    False    False      False           False
# 2            False     False    False    False      False           False
# 3             True     False    False    False      False           False
# 4             True     False    False    False      False           False
# ...            ...       ...      ...      ...        ...             ...
# 2925          True     False    False    False      False           False
# 2926          True     False    False    False      False           False
# 2927         False     False    False    False      False           False
# 2928          True     False    False    False      False           False
# 2929          True     False    False    False      False           False
#
#       SalePrice
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 2925      False
# 2926      False
# 2927      False
# 2928      False
# 2929      False
#
# [2930 rows x 82 columns]

# %%
missing_data=Ames_dataset.isnull().sum()
missing_data
print(missing_data[missing_data > 0])
# Out:
# Lot Frontage       490
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64

# %%
# Fill missing values for categorical columns
Ames_dataset['Alley'].fillna('No Alley', inplace=True)
Ames_dataset['Mas Vnr Type'].fillna('None', inplace=True)
Ames_dataset['Bsmt Qual'].fillna('No Basement', inplace=True)
Ames_dataset['Bsmt Cond'].fillna('No Basement', inplace=True)
Ames_dataset['Bsmt Exposure'].fillna('No Exposure', inplace=True)
Ames_dataset['BsmtFin Type 1'].fillna('No Basement', inplace=True)
Ames_dataset['BsmtFin Type 2'].fillna('No Basement', inplace=True)
Ames_dataset['Garage Yr Blt'].fillna(0, inplace=True)
Ames_dataset['Garage Finish'].fillna('No Garage', inplace=True)
Ames_dataset['Garage Qual'].fillna('No Garage', inplace=True)
Ames_dataset['Garage Cond'].fillna('No Garage', inplace=True)
Ames_dataset['Fence'].fillna('No Fence', inplace=True)
Ames_dataset['Misc Feature'].fillna('None', inplace=True)
Ames_dataset['Fireplace Qu'].fillna('No Fireplace', inplace=True)
Ames_dataset['Garage Type'].fillna('No Garage', inplace=True)
Ames_dataset['Pool QC'].fillna('No Pool', inplace=True)
Ames_dataset['Electrical'].fillna(Ames_dataset['Electrical'].mode()[0], inplace=True)

# Fill missing values for numerical columns

Ames_dataset['BsmtFin SF 1'].fillna(0, inplace=True)
Ames_dataset['BsmtFin SF 2'].fillna(0, inplace=True)
Ames_dataset['Bsmt Unf SF'].fillna(0, inplace=True)
Ames_dataset['Total Bsmt SF'].fillna(0, inplace=True)
Ames_dataset['Bsmt Full Bath'].fillna(0, inplace=True)
Ames_dataset['Bsmt Half Bath'].fillna(0, inplace=True)
Ames_dataset['Garage Cars'].fillna(0, inplace=True)
Ames_dataset['Garage Area'].fillna(0, inplace=True)

# %% [markdown]
# # 1. For Mas Vnr Area, median imputation is appropriate given the small amount of missing data.
#
#
#     Imputation with Median or Mean:
#
#    This is a common approach for numerical features with missing values. Using the median is often preferable as it is less sensitive to outliers.

# %%
Ames_dataset['Mas Vnr Area'].fillna(Ames_dataset['Mas Vnr Area'].median(), inplace=True)

# %% [markdown]
# # 1. Predictive Imputation
# Why Feasible:
#
# Relationship Utilization: Predictive imputation methods like k-Nearest Neighbors (k-NN) or regression models can leverage relationships between Lot Frontage and other features in the dataset.
# Accuracy: These methods can potentially provide better imputation accuracy by considering the context provided by other features.
# How to Implement:
#
# k-NN Imputation:

# %%
from sklearn.impute import KNNImputer

# Using k-NN imputer
imputer = KNNImputer(n_neighbors=5)
Ames_dataset[['Lot Frontage']] = imputer.fit_transform(Ames_dataset[['Lot Frontage']])

# %%
data=Ames_dataset.isnull().sum()
data[data>0]
# Out:
# Series([], dtype: int64)

# %%
##Exploratory data analysis
# In the case of any regression problem the first thing / code that we should run is correlation
# correlation help us figure out how our independent and output features are corelated
# If they are highly +ve or -vely corelated this means that our model prefromance will be high

# %%
# in correlation fn bydeafult correlation is pearson correlation checks relationship 
# between 2 features x and y whether they are highly +ve corelated or highly -ve corelated or 
# not corelated at all . output ranges between -1 to 1. more towards -1 h-velycorelated same for +1
# if toward zero hardly corelated at all

# %%
# here basically 2 type of corelation needs to be checked , the corelation between independent features
#and the corelation between Dependent and independent feature
# if there is high corelation between 2 independent features (+ve or -ve) then we can remove or drop any one of them bcz
# that is called multicolinearity.as we need to check for multicolinearity in linear regression
# criteria for high corelation is .88 .90+ minimum for -ve,+ve both  
# basically it is different for different different fields high corelation criteria, ex: avgrom,avgbedrom

# %%
# Feature Engineering
Ames_dataset['TotalFinishedSF'] = Ames_dataset['BsmtFin SF 1'] + Ames_dataset['BsmtFin SF 2'] + Ames_dataset['1st Flr SF'] + Ames_dataset['2nd Flr SF']
Ames_dataset['TotalBath'] = Ames_dataset['Full Bath'] + Ames_dataset['Half Bath'] + Ames_dataset['Bsmt Full Bath'] + Ames_dataset['Bsmt Half Bath']
Ames_dataset['HouseAge'] = Ames_dataset['Yr Sold'] - Ames_dataset['Year Built']
Ames_dataset['RemodAge'] = Ames_dataset['Yr Sold'] - Ames_dataset['Year Remod/Add']
Ames_dataset['HasPool'] = Ames_dataset['Pool Area'].apply(lambda x: 1 if x > 0 else 0)
Ames_dataset['HasGarage'] = Ames_dataset['Garage Area'].apply(lambda x: 1 if x > 0 else 0)
Ames_dataset['HasFireplace'] = Ames_dataset['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)


# One-hot encode categorical variables
Ames_dataset_encoded = pd.get_dummies(Ames_dataset ,drop_first=True)
# Correlation matrix
corr_matrix = Ames_dataset_encoded.corr()
# Get the top 10 features that have the highest correlation with SalePrice
top_features = corr_matrix['SalePrice'].abs().sort_values(ascending=False).head(125).index.tolist()
# Remove 'SalePrice' from the list
top_features.remove('SalePrice')

# %%
all_feature_names = Ames_dataset_encoded.columns.tolist()
top_feature_indices = [all_feature_names.index(feature) for feature in top_features]
top_feature_indices
# Out:
# [5,
#  39,
#  17,
#  27,
#  28,
#  13,
#  14,
#  40,
#  171,
#  41,
#  7,
#  20,
#  42,
#  8,
#  224,
#  177,
#  9,
#  24,
#  45,
#  234,
#  25,
#  196,
#  185,
#  170,
#  87,
#  10,
#  245,
#  167,
#  233,
#  241,
#  191,
#  276,
#  284,
#  176,
#  237,
#  3,
#  215,
#  146,
#  162,
#  29,
#  30,
#  222,
#  168,
#  57,
#  86,
#  51,
#  21,
#  193,
#  124,
#  255,
#  18,
#  257,
#  15,
#  4,
#  216,
#  122,
#  250,
#  26,
#  1,
#  165,
#  50,
#  220,
#  93,
#  242,
#  44,
#  248,
#  253,
#  243,
#  239,
#  182,
#  119,
#  88,
#  279,
#  58,
#  83,
#  12,
#  265,
#  79,
#  147,
#  244,
#  163,
#  75,
#  246,
#  92,
#  199,
#  181,
#  198,
#  183,
#  188,
#  263,
#  236,
#  204,
#  194,
#  251,
#  221,
#  141,
#  22,
#  63,
#  138,
#  283,
#  172,
#  153,
#  186,
#  71,
#  156,
#  213,
#  94,
#  212,
#  31,
#  90,
#  169,
#  217,
#  106,
#  195,
#  53,
#  81,
#  23,
#  231,
#  133,
#  175,
#  46,
#  96,
#  178,
#  206]

# %%
import seaborn as sns

# %%
#Checking the relationship between dependent and independent fetures
plt.scatter(Ames_dataset['SalePrice'],Ames_dataset['Lot Area']);
plt.xlabel('SalePrice');
plt.ylabel('Lot Area');

# %%
plt.scatter(Ames_dataset['SalePrice'],Ames_dataset['Overall Qual']);
plt.xlabel('SalePrice');
plt.ylabel('Overall Qual');

# %%
plt.scatter(Ames_dataset['SalePrice'],Ames_dataset['Year Built']);
plt.xlabel('SalePrice');
plt.ylabel('Year Built');

# %%
sns.regplot(x='Year Built',y='SalePrice',data=Ames_dataset)
# Out:
# <Axes: xlabel='Year Built', ylabel='SalePrice'>

# %%
sns.regplot(x='Overall Qual',y='SalePrice',data=Ames_dataset)
# Out:
# <Axes: xlabel='Overall Qual', ylabel='SalePrice'>

# %%
sns.regplot(x='Lot Area',y='SalePrice',data=Ames_dataset)
# Out:
# <Axes: xlabel='Lot Area', ylabel='SalePrice'>

# %%
# In an dataset some sense of linearnity or an relationship must be there such as x Inc then YInc or dec and viceversa
# to create an better regression model
# For a regression model to perform well, there should ideally be a reasonably strong correlation between the predictors and the outcome variable, ensuring that the model can effectively capture the relationships in the data.

# %%
sns.regplot(x='Bedroom AbvGr',y='SalePrice',data=Ames_dataset)
# Out:
# <Axes: xlabel='Bedroom AbvGr', ylabel='SalePrice'>

# %%
#Create an Model
#creating independent and dependent features
#we have to do train , test, split
Ames_dataset_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Columns: 285 entries, Order to Sale Condition_Partial
# dtypes: bool(239), float64(13), int64(33)
# memory usage: 1.7 MB

# %% [markdown]
# ## MODEL CREATION

# %%
#Independent and dependent features 
#contain all datapoint and independent feature
#The iloc method in pandas is used to access elements, rows, and columns of a DataFrame or Series by integer-based indexing. The syntax iloc[x, y] is used to select specific data from a DataFrame, where:


from sklearn.linear_model import LinearRegression


# Define X and y
X = Ames_dataset_encoded[top_features]
y = Ames_dataset_encoded['SalePrice']

# %%
X.head()
# Out:
#    Overall Qual  TotalFinishedSF  Gr Liv Area  Garage Cars  Garage Area  \
# 0             6           2295.0         1656          2.0        528.0
# 1             5           1508.0          896          1.0        730.0
# 2             6           2252.0         1329          1.0        312.0
# 3             7           3175.0         2110          2.0        522.0
# 4             5           2420.0         1629          2.0        482.0
#
#    Total Bsmt SF  1st Flr SF  TotalBath  Exter Qual_TA  HouseAge  ...  \
# 0         1080.0        1656        2.0           True        50  ...
# 1          882.0         896        1.0           True        49  ...
# 2         1329.0        1329        2.0           True        52  ...
# 3         2110.0        2110        4.0          False        42  ...
# 4          928.0         928        3.0           True        13  ...
#
#    Alley_No Alley  Neighborhood_MeadowV  Kitchen AbvGr  Functional_Typ  \
# 0            True                 False              1            True
# 1            True                 False              1            True
# 2            True                 False              1            True
# 3            True                 False              1            True
# 4            True                 False              1            True
#
#    Roof Matl_WdShngl  Exter Cond_TA  MS Zoning_C (all)  Condition 1_Feedr  \
# 0              False           True              False              False
# 1              False           True              False               True
# 2              False           True              False              False
# 3              False           True              False              False
# 4              False           True              False              False
#
#    Foundation_Slab  BsmtFin Type 2_Unf
# 0            False                True
# 1            False               False
# 2            False                True
# 3            False                True
# 4            False                True
#
# [5 rows x 124 columns]

# %%
y.head()
# Out:
# 0    215000
# 1    105000
# 2    172000
# 3    244000
# 4    189900
# Name: SalePrice, dtype: int64

# %%
#Performance matrix
#Whenever we get our dataset we should do an train test split, keeping the test dataset seperately 
# once we create our model then we will test with the test dataset to check it performance
# other then that we will use our training dataset to check model performance

# %% [markdown]
# ## TRAIN_TEST_SPLIT

# %%
#Train_Test_Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.18, random_state=22)

# %%
X_train
# Out:
#       Overall Qual  TotalFinishedSF  Gr Liv Area  Garage Cars  Garage Area  \
# 456             10           4638.0         2492          3.0        949.0
# 2719             5           2418.0         1920          2.0        451.0
# 1463             7           2318.0         1768          2.0        543.0
# 1913             5           1368.0          912          1.0        275.0
# 1933             6           2080.0         1040          1.0        293.0
# ...            ...              ...          ...          ...          ...
# 2550             5           1880.0         1248          1.0        286.0
# 1382             6           1484.0         1034          2.0        504.0
# 356              6           1571.0         1571          2.0        380.0
# 812              5           2240.0         2240          2.0        528.0
# 2180            10           9105.0         5095          3.0       1154.0
#
#       Total Bsmt SF  1st Flr SF  TotalBath  Exter Qual_TA  HouseAge  ...  \
# 456          2492.0        2492        4.0          False         5  ...
# 2719         1052.0        1252        3.0          False        48  ...
# 1463          884.0         884        4.0          False         5  ...
# 1913          912.0         912        1.0           True        49  ...
# 1933         1040.0        1040        2.0           True        54  ...
# ...             ...         ...        ...            ...       ...  ...
# 2550         1248.0        1248        2.0           True        46  ...
# 1382          450.0        1034        2.0           True        30  ...
# 356           799.0         799        3.0          False        16  ...
# 812             0.0        1120        2.0           True        30  ...
# 2180         5095.0        5095        5.0          False        -1  ...
#
#       Alley_No Alley  Neighborhood_MeadowV  Kitchen AbvGr  Functional_Typ  \
# 456             True                 False              1            True
# 2719            True                 False              1            True
# 1463            True                 False              1            True
# 1913            True                 False              1            True
# 1933            True                 False              1            True
# ...              ...                   ...            ...             ...
# 2550            True                 False              1            True
# 1382            True                 False              1            True
# 356             True                 False              1            True
# 812             True                 False              2            True
# 2180            True                 False              1            True
#
#       Roof Matl_WdShngl  Exter Cond_TA  MS Zoning_C (all)  Condition 1_Feedr  \
# 456               False           True              False              False
# 2719              False          False              False              False
# 1463              False           True              False              False
# 1913              False           True              False               True
# 1933              False           True              False              False
# ...                 ...            ...                ...                ...
# 2550              False           True              False              False
# 1382              False           True              False              False
# 356               False           True              False              False
# 812               False           True              False               True
# 2180              False           True              False              False
#
#       Foundation_Slab  BsmtFin Type 2_Unf
# 456             False                True
# 2719            False               False
# 1463            False                True
# 1913            False                True
# 1933            False               False
# ...               ...                 ...
# 2550            False                True
# 1382            False                True
# 356             False                True
# 812              True               False
# 2180            False                True
#
# [2402 rows x 124 columns]

# %%
X_test
# Out:
#       Overall Qual  TotalFinishedSF  Gr Liv Area  Garage Cars  Garage Area  \
# 1227             5           1567.0         1036          1.0        312.0
# 373              6           2848.0         1602          2.0        529.0
# 115              6           2363.0         1381          2.0        676.0
# 978              4           1344.0         1344          0.0          0.0
# 2783             6           2277.0         1282          3.0        672.0
# ...            ...              ...          ...          ...          ...
# 304              4           1128.0         1128          2.0        528.0
# 2439             6           2457.0         1671          2.0        472.0
# 2677             3           1509.0         1162          1.0        258.0
# 525              8           1953.0         1953          3.0       1043.0
# 225              5           2692.0         1373          2.0        591.0
#
#       Total Bsmt SF  1st Flr SF  TotalBath  Exter Qual_TA  HouseAge  ...  \
# 1227         1036.0        1036        1.0           True        55  ...
# 373          1602.0        1602        3.0          False        32  ...
# 115          1161.0        1381        3.0           True        38  ...
# 978           546.0         798        2.0           True        39  ...
# 2783          995.0        1282        3.0           True        28  ...
# ...             ...         ...        ...            ...       ...  ...
# 304           698.0         698        1.0           True        90  ...
# 2439          959.0         959        4.0           True         6  ...
# 2677          728.0         728        2.0          False        76  ...
# 525          1082.0        1082        3.0          False         4  ...
# 225          1319.0        1373        2.0           True        32  ...
#
#       Alley_No Alley  Neighborhood_MeadowV  Kitchen AbvGr  Functional_Typ  \
# 1227            True                 False              1            True
# 373             True                 False              1            True
# 115             True                 False              1            True
# 978             True                  True              1            True
# 2783            True                 False              1            True
# ...              ...                   ...            ...             ...
# 304             True                 False              1            True
# 2439            True                 False              1            True
# 2677            True                 False              1            True
# 525             True                 False              1            True
# 225             True                 False              1            True
#
#       Roof Matl_WdShngl  Exter Cond_TA  MS Zoning_C (all)  Condition 1_Feedr  \
# 1227              False           True              False              False
# 373               False           True              False              False
# 115               False           True              False              False
# 978               False           True              False              False
# 2783              False           True              False              False
# ...                 ...            ...                ...                ...
# 304               False          False               True              False
# 2439              False           True              False              False
# 2677              False           True              False              False
# 525               False           True              False              False
# 225               False           True              False              False
#
#       Foundation_Slab  BsmtFin Type 2_Unf
# 1227            False                True
# 373             False                True
# 115             False                True
# 978             False                True
# 2783            False               False
# ...               ...                 ...
# 304             False                True
# 2439            False                True
# 2677            False                True
# 525             False                True
# 225             False                True
#
# [528 rows x 124 columns]

# %%
#Standard scaling / Standard scale R
#before doing model tarining , we need to do standard scale r vv imp step because as per math #intution behind linear regresiion problem, we alwways use gradient decent , our main aim in LR is to come near global minima, every independent feature unit  in our data set is calculated with respect to diff diff units .One imp step so that our conversioning of the gradient decent algorithm will take faster  
# we have to normalize or standard all the datapoints to the same scale that should be based on standardize scaler
#REason for standardization of dataset:	we alwways use gradient decent , our main aim in LR is to come near global minima, every independent feature unit  in our data set should be in same scale , beacuse of that the conversion will happen quickly.

# %% [markdown]
# ## STANDARDIZING THE DATASET

# %%
#STnadard the dataset
#scaler will conatin the object
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#learn lr model

# %% [markdown]
# # MODEL TRAINING

# %%
# whENEVER WE solve regression problem 2 imp things will be there 1. coefficients 2. Intercept

# %%
from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
# Train the Linear Regression model
lin_reg = LinearRegression()


#  This line creates an instance of the LinearRegression class and assigns it to the variable regression. This instance represents a linear regression model, which is used to predict a continuous target variable based on one or more input features. regression.fit(X_train, y_train):

# %%
lin_reg.fit(X_train_scaled, y_train)

# This line trains the linear regression model using the training data. X_train is a 2D array or DataFrame containing the input features, and y_train is a 1D array or Series containing the target variable. The fit method calculates the best-fit line (or hyperplane in the case of multiple features) that minimizes the error between the predicted and actual target values.
# Out:
# LinearRegression()

# %%
lin_reg.coef_
# no of coef= no of independent features, 
# bcz for every independnt feature there will be an coefficient 
# IT indicate an unit increase in 1st independt feature will affect 8.49221760e-01 the target variable means the TV will incrasee at this rate
# Out:
# array([ 1.14632957e+04, -2.21304730e+16, -5.08369712e+02,  7.39713622e+03,
#         6.25135071e+02,  1.27057309e+16,  1.14296727e+16, -3.30682431e+03,
#        -1.04382006e+04,  5.93852547e+16,  5.93295902e+16,  4.60660865e+03,
#        -4.07298977e+16, -4.07668302e+16, -1.25106590e+04,  7.47373618e+02,
#         3.87964302e+03, -2.63580981e+02, -2.63022065e+16, -2.63022065e+16,
#         5.48340660e+03,  2.45566615e+03, -8.35890760e+03, -9.40347998e+03,
#         8.28017893e+03,  8.91785151e+02, -1.91965854e+03,  7.90011511e+03,
#        -3.99433074e+02,  2.65685585e+03,  4.76202286e+03,  1.29983664e+03,
#         3.07298935e+03,  3.88000000e+02,  4.12300000e+03, -2.98000000e+02,
#        -1.70200000e+03, -1.54600000e+03,  3.24700000e+03,  1.78453125e+02,
#        -7.76000000e+02, -1.09965000e+04,  3.53500000e+03, -4.60000000e+02,
#        115319.25324407, 133240.36416268, 232304.25324407, 102549.36302747,
#        138797.95237796, 180744.58626092, 236931.4672813 , 123324.86614766,
#        145535.84744271, 121893.33920292,  76029.05905893, 123651.32123891,
#        191716.58626092, 180655.1468525 , 193468.15923613, 154229.43004701,
#        321728.91927776, 127364.18486495, 237474.81515637, 127601.18910259,
#        159101.36416268, 124988.86416268, 328710.76109671, 289545.41927776,
#        173001.95237796, 159853.40035662, 344456.58626092, 181401.98296166,
#        122965.82123891, 220319.1178118 , 368155.24116408, 157893.74116408,
#         55289.39461102, 156741.95237796, 124914.22604827, 118477.79541465,
#        106342.27242192, 294437.58626092, 105580.04575746, 385803.98822207,
#        126860.96390642, 161279.47973487, 139278.84798802, 377471.82123891,
#        172314.08626092,  93147.96917299, 135671.08626092, 124937.82123891,
#         89264.85425061, 329218.76109671,  94450.80406769, 160011.81630411,
#        338781.03833681, 149761.34798802, 146394.73027973, 212909.58626092,
#        192837.64912269, 112389.44080781, 105482.08626092, 124738.92797529,
#        157248.36325706, 320272.05776818, 131435.08626092, 117674.58626092,
#        120219.89726289, 153570.88617909,  79620.54044197, 241595.00618608,
#        138436.12068064, 170831.84798802, 176925.93295449, 232066.04807139,
#        195161.58626092, 185370.1468525 , 164771.48822207, 162864.28893568,
#        317558.83920292, 192684.71274062, 202026.63104262, 202820.08626092,
#        103207.7172828 , 155333.44771861, 158324.63689244, 205115.78969807,
#         77039.8350369 , 344184.91927776, 189115.95237796, 228762.33920292,
#        301955.82123891, 143604.95591884, 212455.44300053, 136091.21274062,
#        153232.57688348,  91044.82250327, 127280.25324407, 264960.25324407,
#        121831.05094432, 103759.46010224, 263704.08626092, 448491.34117154,
#         96869.25324407, 165544.38917988,  74755.10206341,  87096.95594727,
#        197922.58626092,  86710.53275707, 240919.54398125, 182450.043882  ])

# %% [markdown]
# # Performance Matrix

# %%
## plot an scatter plot for prediction
plt.scatter(y_test, y_pred)
plt.xlabel('Actual SalePrice')
plt.ylabel('Predicted SalePrice')
plt.title('Actual vs Predicted SalePrice')
plt.show()

# %%
#Residuals (error)
residuals=y_test-y_pred

# %%
sns.displot(residuals,kind="kde")

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 15108.21637761807
# 619517981.4867281
# 24890.11814931235

# %% [markdown]
# # R square and adjusted R square
# ### Formula
#
# ### R^2 = 1 - SSR/SST
#
#  ### R^2 = coefficient of determination SSR = sum of squares of residuals SST = total sum of squares
# the more toward 1 the better it is. sometime also vary on problem statement

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.8826683175506747

# %% [markdown]
# # Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]
#
# ### where:
#
# ### R2: The R2 of the model n: The number of observations k: The number of predictor variables
# Adjusted R2 we be always less than R2

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.8465662614124208

# %%
# Step 1: Extract a single row from the dataset
new_data = Ames_dataset.loc[[0]].copy()  # Select the first row

# Fill missing values and apply feature engineering (same as for Ames_dataset)
# Fill missing values for categorical columns

# Fill missing values for categorical columns
new_data['Alley'].fillna('No Alley', inplace=True)
new_data['Mas Vnr Type'].fillna('None', inplace=True)
new_data['Bsmt Qual'].fillna('No Basement', inplace=True)
new_data['Bsmt Cond'].fillna('No Basement', inplace=True)
new_data['Bsmt Exposure'].fillna('No Exposure', inplace=True)
new_data['BsmtFin Type 1'].fillna('No Basement', inplace=True)
new_data['BsmtFin Type 2'].fillna('No Basement', inplace=True)
new_data['Garage Yr Blt'].fillna(0, inplace=True)
new_data['Garage Finish'].fillna('No Garage', inplace=True)
new_data['Garage Qual'].fillna('No Garage', inplace=True)
new_data['Garage Cond'].fillna('No Garage', inplace=True)
new_data['Fence'].fillna('No Fence', inplace=True)
new_data['Misc Feature'].fillna('None', inplace=True)
new_data['Fireplace Qu'].fillna('No Fireplace', inplace=True)
new_data['Garage Type'].fillna('No Garage', inplace=True)
new_data['Pool QC'].fillna('No Pool', inplace=True)
new_data['Electrical'].fillna(Ames_dataset['Electrical'].mode()[0], inplace=True)

# Fill missing values for numerical columns
new_data['BsmtFin SF 1'].fillna(0, inplace=True)
new_data['BsmtFin SF 2'].fillna(0, inplace=True)
new_data['Bsmt Unf SF'].fillna(0, inplace=True)
new_data['Total Bsmt SF'].fillna(0, inplace=True)
new_data['Bsmt Full Bath'].fillna(0, inplace=True)
new_data['Bsmt Half Bath'].fillna(0, inplace=True)
new_data['Garage Cars'].fillna(0, inplace=True)
new_data['Garage Area'].fillna(0, inplace=True)
new_data['Mas Vnr Area'].fillna(Ames_dataset['Mas Vnr Area'].median(), inplace=True)

# Using the same KNN imputer
imputer = KNNImputer(n_neighbors=5)
new_data[['Lot Frontage']] = imputer.fit_transform(new_data[['Lot Frontage']])

# Apply feature engineering
new_data['TotalFinishedSF'] = new_data['BsmtFin SF 1'] + new_data['BsmtFin SF 2'] + new_data['1st Flr SF'] + new_data['2nd Flr SF']
new_data['TotalBath'] = new_data['Full Bath'] + new_data['Half Bath'] + new_data['Bsmt Full Bath'] + new_data['Bsmt Half Bath']
new_data['HouseAge'] = new_data['Yr Sold'] - new_data['Year Built']
new_data['RemodAge'] = new_data['Yr Sold'] - new_data['Year Remod/Add']
new_data['HasPool'] = new_data['Pool Area'].apply(lambda x: 1 if x > 0 else 0)
new_data['HasGarage'] = new_data['Garage Area'].apply(lambda x: 1 if x > 0 else 0)
new_data['HasFireplace'] = new_data['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)

new_data_encoded = pd.get_dummies(new_data, drop_first=True)


# Align new data columns with top features
# Use intersection of columns
new_data_encoded = new_data_encoded.reindex(columns=X.columns, fill_value=0)

# Transform the data to match the training data scaling
new_data_scaled = scaler.transform(new_data_encoded)

# Predict using the trained model
predicted_price = lin_reg.predict(new_data_scaled)

print(f'Predicted Sale Price: {predicted_price[0]}')
Ames_dataset.loc[0,'SalePrice']
# Out:
# Predicted Sale Price: 216067.2870341692
# 215000

# %%
# NOW pickle the model file to use it for deployment
import pickle

# %%
pickle.dump(lin_reg,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
## Prediction
pickled_model.predict(new_data_scaled)
# Out:
# array([216067.28703417])
