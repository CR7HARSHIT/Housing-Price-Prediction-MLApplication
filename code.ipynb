# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
#FOR inline display of graph and visualization

# %%
#Let's load the Ames house pricing dataset
Ames_dataset=pd.read_csv("AmesHousing.csv")

# %%
#In an dataset there we be one output/dependent feature and rest will be independent feature
Ames_dataset
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2      NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3      NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4      NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2925   NaN       IR1          Lvl  ...         0     NaN  GdPrv          NaN
# 2926   NaN       IR1          Low  ...         0     NaN  MnPrv          NaN
# 2927   NaN       Reg          Lvl  ...         0     NaN  MnPrv         Shed
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# 2       12500       6    2010       WD           Normal     172000
# 3           0       4    2010       WD           Normal     244000
# 4           0       3    2010       WD           Normal     189900
# ...       ...     ...     ...       ...             ...        ...
# 2925        0       3    2006       WD           Normal     142500
# 2926        0       6    2006       WD           Normal     131000
# 2927      700       7    2006       WD           Normal     132000
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %%
Ames_dataset.keys()
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'Sale Condition', 'SalePrice'],
#       dtype='object')

# %%
Ames_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
#  16  Bldg Type        2930 non-null   object
#  17  House Style      2930 non-null   object
#  18  Overall Qual     2930 non-null   int64
#  19  Overall Cond     2930 non-null   int64
#  20  Year Built       2930 non-null   int64
#  21  Year Remod/Add   2930 non-null   int64
#  22  Roof Style       2930 non-null   object
#  23  Roof Matl        2930 non-null   object
#  24  Exterior 1st     2930 non-null   object
#  25  Exterior 2nd     2930 non-null   object
#  26  Mas Vnr Type     1155 non-null   object
#  27  Mas Vnr Area     2907 non-null   float64
#  28  Exter Qual       2930 non-null   object
#  29  Exter Cond       2930 non-null   object
#  30  Foundation       2930 non-null   object
#  31  Bsmt Qual        2850 non-null   object
#  32  Bsmt Cond        2850 non-null   object
#  33  Bsmt Exposure    2847 non-null   object
#  34  BsmtFin Type 1   2850 non-null   object
#  35  BsmtFin SF 1     2929 non-null   float64
#  36  BsmtFin Type 2   2849 non-null   object
#  37  BsmtFin SF 2     2929 non-null   float64
#  38  Bsmt Unf SF      2929 non-null   float64
#  39  Total Bsmt SF    2929 non-null   float64
#  40  Heating          2930 non-null   object
#  41  Heating QC       2930 non-null   object
#  42  Central Air      2930 non-null   object
#  43  Electrical       2929 non-null   object
#  44  1st Flr SF       2930 non-null   int64
#  45  2nd Flr SF       2930 non-null   int64
#  46  Low Qual Fin SF  2930 non-null   int64
#  47  Gr Liv Area      2930 non-null   int64
#  48  Bsmt Full Bath   2928 non-null   float64
#  49  Bsmt Half Bath   2928 non-null   float64
#  50  Full Bath        2930 non-null   int64
#  51  Half Bath        2930 non-null   int64
#  52  Bedroom AbvGr    2930 non-null   int64
#  53  Kitchen AbvGr    2930 non-null   int64
#  54  Kitchen Qual     2930 non-null   object
#  55  TotRms AbvGrd    2930 non-null   int64
#  56  Functional       2930 non-null   object
#  57  Fireplaces       2930 non-null   int64
#  58  Fireplace Qu     1508 non-null   object
#  59  Garage Type      2773 non-null   object
#  60  Garage Yr Blt    2771 non-null   float64
#  61  Garage Finish    2771 non-null   object
#  62  Garage Cars      2929 non-null   float64
#  63  Garage Area      2929 non-null   float64
#  64  Garage Qual      2771 non-null   object
#  65  Garage Cond      2771 non-null   object
#  66  Paved Drive      2930 non-null   object
#  67  Wood Deck SF     2930 non-null   int64
#  68  Open Porch SF    2930 non-null   int64
#  69  Enclosed Porch   2930 non-null   int64
#  70  3Ssn Porch       2930 non-null   int64
#  71  Screen Porch     2930 non-null   int64
#  72  Pool Area        2930 non-null   int64
#  73  Pool QC          13 non-null     object
#  74  Fence            572 non-null    object
#  75  Misc Feature     106 non-null    object
#  76  Misc Val         2930 non-null   int64
#  77  Mo Sold          2930 non-null   int64
#  78  Yr Sold          2930 non-null   int64
#  79  Sale Type        2930 non-null   object
#  80  Sale Condition   2930 non-null   object
#  81  SalePrice        2930 non-null   int64
# dtypes: float64(11), int64(28), object(43)
# memory usage: 1.8+ MB

# %%
Ames_dataset.head(50)
# Out:
#     Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0       1  526301100           20        RL         141.0     31770   Pave
# 1       2  526350040           20        RH          80.0     11622   Pave
# 2       3  526351010           20        RL          81.0     14267   Pave
# 3       4  526353030           20        RL          93.0     11160   Pave
# 4       5  527105010           60        RL          74.0     13830   Pave
# 5       6  527105030           60        RL          78.0      9978   Pave
# 6       7  527127150          120        RL          41.0      4920   Pave
# 7       8  527145080          120        RL          43.0      5005   Pave
# 8       9  527146030          120        RL          39.0      5389   Pave
# 9      10  527162130           60        RL          60.0      7500   Pave
# 10     11  527163010           60        RL          75.0     10000   Pave
# 11     12  527165230           20        RL           NaN      7980   Pave
# 12     13  527166040           60        RL          63.0      8402   Pave
# 13     14  527180040           20        RL          85.0     10176   Pave
# 14     15  527182190          120        RL           NaN      6820   Pave
# 15     16  527216070           60        RL          47.0     53504   Pave
# 16     17  527225035           50        RL         152.0     12134   Pave
# 17     18  527258010           20        RL          88.0     11394   Pave
# 18     19  527276150           20        RL         140.0     19138   Pave
# 19     20  527302110           20        RL          85.0     13175   Pave
# 20     21  527358140           20        RL         105.0     11751   Pave
# 21     22  527358200           85        RL          85.0     10625   Pave
# 22     23  527368020           60        FV           NaN      7500   Pave
# 23     24  527402200           20        RL           NaN     11241   Pave
# 24     25  527402250           20        RL           NaN     12537   Pave
# 25     26  527403020           20        RL          65.0      8450   Pave
# 26     27  527404120           20        RL          70.0      8400   Pave
# 27     28  527425090           20        RL          70.0     10500   Pave
# 28     29  527427230          120        RH          26.0      5858   Pave
# 29     30  527451180          160        RM          21.0      1680   Pave
# 30     31  527451330          160        RM          21.0      1680   Pave
# 31     32  527451410          160        RM          21.0      1680   Pave
# 32     33  527452190          120        RL          53.0      4043   Pave
# 33     34  527453130          160        RL          24.0      2280   Pave
# 34     35  527453150          120        RL          24.0      2280   Pave
# 35     36  527454200          160        RL          24.0      2280   Pave
# 36     37  528108120           60        RL         102.0     12858   Pave
# 37     38  528112020           20        RL          98.0     11478   Pave
# 38     39  528120060           20        RL          83.0     10159   Pave
# 39     40  528120090           20        RL          94.0     12883   Pave
# 40     41  528120100           20        RL          95.0     12182   Pave
# 41     42  528120120           20        RL          90.0     11520   Pave
# 42     43  528138020           20        RL          79.0     14122   Pave
# 43     44  528138060           20        RL          70.0     10171   Pave
# 44     45  528150070           20        RL         100.0     12919   Pave
# 45     46  528175010          120        RL          44.0      6371   Pave
# 46     47  528176010           20        RL         110.0     14300   Pave
# 47     48  528176070           60        RL         105.0     13650   Pave
# 48     49  528180070          120        RL          61.0      7658   Pave
# 49     50  528181050          120        RL          41.0      7132   Pave
#
#    Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0    NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1    NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2    NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3    NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4    NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# 5    NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 6    NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 7    NaN       IR1          HLS  ...         0     NaN    NaN          NaN
# 8    NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 9    NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 10   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 11   NaN       IR1          Lvl  ...         0     NaN  GdPrv         Shed
# 12   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 13   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 14   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 15   NaN       IR2          HLS  ...         0     NaN    NaN          NaN
# 16   NaN       IR1          Bnk  ...         0     NaN    NaN          NaN
# 17   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 18   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 19   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 20   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# 21   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 22   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 23   NaN       IR1          Lvl  ...         0     NaN    NaN         Shed
# 24   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 25   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 26   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 27   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 28   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 29   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 30   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 31   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 32   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 33   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 34   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 35   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 36   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 37   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 38   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 39   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 40   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 41   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 42   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 43   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 44   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 45   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 46   NaN       Reg          HLS  ...         0     NaN    NaN          NaN
# 47   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 48   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 49   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
#
#    Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0         0       5    2010       WD           Normal     215000
# 1         0       6    2010       WD           Normal     105000
# 2     12500       6    2010       WD           Normal     172000
# 3         0       4    2010       WD           Normal     244000
# 4         0       3    2010       WD           Normal     189900
# 5         0       6    2010       WD           Normal     195500
# 6         0       4    2010       WD           Normal     213500
# 7         0       1    2010       WD           Normal     191500
# 8         0       3    2010       WD           Normal     236500
# 9         0       6    2010       WD           Normal     189000
# 10        0       4    2010       WD           Normal     175900
# 11      500       3    2010       WD           Normal     185000
# 12        0       5    2010       WD           Normal     180400
# 13        0       2    2010       WD           Normal     171500
# 14        0       6    2010       WD           Normal     212000
# 15        0       6    2010       WD           Normal     538000
# 16        0       6    2010       WD           Normal     164000
# 17        0       6    2010       New         Partial     394432
# 18        0       6    2010       WD           Normal     141000
# 19        0       2    2010       WD           Normal     210000
# 20        0       1    2010       COD          Normal     190000
# 21        0       1    2010       WD           Family     170000
# 22        0       1    2010       WD           Normal     216000
# 23      700       3    2010       WD           Normal     149000
# 24        0       4    2010       WD           Normal     149900
# 25        0       7    2010       WD           Normal     142000
# 26        0       4    2010       WD           Normal     126000
# 27        0       4    2010     ConLI          Normal     115000
# 28        0       6    2010       WD           Normal     184000
# 29        0       2    2010       COD          Normal      96000
# 30        0       3    2010       WD           Normal     105500
# 31        0       3    2010       WD           Family      88000
# 32        0       7    2010       WD           Normal     127500
# 33        0       6    2010       WD           Normal     149900
# 34        0       6    2010       WD           Normal     120000
# 35        0       7    2010       WD           Normal     146000
# 36        0       1    2010       New         Partial     376162
# 37        0       5    2010       WD           Normal     306000
# 38        0       4    2010       New         Partial     395192
# 39        0       6    2010       New         Partial     290941
# 40        0       5    2010       New         Partial     220000
# 41        0       6    2010       WD           Normal     275000
# 42        0       2    2010       WD           Normal     259000
# 43        0       3    2010       WD           Normal     214000
# 44        0       3    2010       New         Partial     611657
# 45        0       6    2010       New         Partial     224000
# 46        0       6    2010       WD           Normal     500000
# 47        0       6    2010       WD           Normal     320000
# 48        0       2    2010       WD           Normal     319900
# 49        0       4    2010       WD           Normal     205000
#
# [50 rows x 82 columns]

# %%
#Summarizing the stats of data
Ames_dataset.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# std        1.411026      1.111537    30.245361       20.860286    179.112611
# min        1.000000      1.000000  1872.000000     1950.000000      0.000000
# 25%        5.000000      5.000000  1954.000000     1965.000000      0.000000
# 50%        6.000000      5.000000  1973.000000     1993.000000      0.000000
# 75%        7.000000      6.000000  2001.000000     2004.000000    164.000000
# max       10.000000      9.000000  2010.000000     2010.000000   1600.000000
#
#        ...  Wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  \
# count  ...   2930.000000    2930.000000     2930.000000  2930.000000
# mean   ...     93.751877      47.533447       23.011604     2.592491
# std    ...    126.361562      67.483400       64.139059    25.141331
# min    ...      0.000000       0.000000        0.000000     0.000000
# 25%    ...      0.000000       0.000000        0.000000     0.000000
# 50%    ...      0.000000      27.000000        0.000000     0.000000
# 75%    ...    168.000000      70.000000        0.000000     0.000000
# max    ...   1424.000000     742.000000     1012.000000   508.000000
#
#        Screen Porch    Pool Area      Misc Val      Mo Sold      Yr Sold  \
# count   2930.000000  2930.000000   2930.000000  2930.000000  2930.000000
# mean      16.002048     2.243345     50.635154     6.216041  2007.790444
# std       56.087370    35.597181    566.344288     2.714492     1.316613
# min        0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%        0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%        0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%        0.000000     0.000000      0.000000     8.000000  2009.000000
# max      576.000000   800.000000  17000.000000    12.000000  2010.000000
#
#            SalePrice
# count    2930.000000
# mean   180796.060068
# std     79886.692357
# min     12789.000000
# 25%    129500.000000
# 50%    160000.000000
# 75%    213500.000000
# max    755000.000000
#
# [8 rows x 39 columns]

# %%
#CHECK THE MISSING VALUES
Ames_dataset.isnull()
# Out:
#       Order    PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  \
# 0     False  False        False      False         False     False   False
# 1     False  False        False      False         False     False   False
# 2     False  False        False      False         False     False   False
# 3     False  False        False      False         False     False   False
# 4     False  False        False      False         False     False   False
# ...     ...    ...          ...        ...           ...       ...     ...
# 2925  False  False        False      False         False     False   False
# 2926  False  False        False      False          True     False   False
# 2927  False  False        False      False         False     False   False
# 2928  False  False        False      False         False     False   False
# 2929  False  False        False      False         False     False   False
#
#       Alley  Lot Shape  Land Contour  ...  Pool Area  Pool QC  Fence  \
# 0      True      False         False  ...      False     True   True
# 1      True      False         False  ...      False     True  False
# 2      True      False         False  ...      False     True   True
# 3      True      False         False  ...      False     True   True
# 4      True      False         False  ...      False     True  False
# ...     ...        ...           ...  ...        ...      ...    ...
# 2925   True      False         False  ...      False     True  False
# 2926   True      False         False  ...      False     True  False
# 2927   True      False         False  ...      False     True  False
# 2928   True      False         False  ...      False     True   True
# 2929   True      False         False  ...      False     True   True
#
#       Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 0             True     False    False    False      False           False
# 1             True     False    False    False      False           False
# 2            False     False    False    False      False           False
# 3             True     False    False    False      False           False
# 4             True     False    False    False      False           False
# ...            ...       ...      ...      ...        ...             ...
# 2925          True     False    False    False      False           False
# 2926          True     False    False    False      False           False
# 2927         False     False    False    False      False           False
# 2928          True     False    False    False      False           False
# 2929          True     False    False    False      False           False
#
#       SalePrice
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 2925      False
# 2926      False
# 2927      False
# 2928      False
# 2929      False
#
# [2930 rows x 82 columns]

# %%
missing_data=Ames_dataset.isnull().sum()
missing_data
print(missing_data[missing_data > 0])
# Out:
# Lot Frontage       490
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64

# %%
Ames_dataset['Alley'].fillna('No Alley', inplace=True)
Ames_dataset['Mas Vnr Type'].fillna('None', inplace=True)
Ames_dataset['Bsmt Qual'].fillna('No Basement', inplace=True)
Ames_dataset['Bsmt Cond'].fillna('No Basement', inplace=True)
Ames_dataset['Bsmt Exposure'].fillna('No Exposure', inplace=True)
Ames_dataset['BsmtFin Type 1'].fillna('No Basement', inplace=True)
Ames_dataset['BsmtFin Type 2'].fillna('No Basement', inplace=True)
Ames_dataset['Garage Yr Blt'].fillna(0, inplace=True)
Ames_dataset['Garage Finish'].fillna('No Garage', inplace=True)
Ames_dataset['Garage Qual'].fillna('No Garage', inplace=True)
Ames_dataset['Garage Cond'].fillna('No Garage', inplace=True)
Ames_dataset['Fence'].fillna('No Fence', inplace=True)
Ames_dataset['Misc Feature'].fillna('None', inplace=True)
Ames_dataset['Fireplace Qu'].fillna('No Fireplace', inplace=True)
Ames_dataset['Garage Type'].fillna('No Garage', inplace=True)
Ames_dataset['Pool QC'].fillna('No Pool', inplace=True)
most_common_electrical = Ames_dataset['Electrical'].mode()[0]
Ames_dataset['Electrical'].fillna(most_common_electrical, inplace=True)
x=Ames_dataset.isnull().sum()
Ames_dataset['BsmtFin SF 1'].fillna(0, inplace=True)
Ames_dataset['BsmtFin SF 2'].fillna(0, inplace=True)
Ames_dataset['Bsmt Unf SF'].fillna(0, inplace=True)
Ames_dataset['Total Bsmt SF'].fillna(0, inplace=True)
# Fill missing values for basement bathrooms with 0
Ames_dataset['Bsmt Full Bath'].fillna(0, inplace=True)
Ames_dataset['Bsmt Half Bath'].fillna(0, inplace=True)

# Fill missing values for garage-related columns with 0
Ames_dataset['Garage Cars'].fillna(0, inplace=True)
Ames_dataset['Garage Area'].fillna(0, inplace=True)

# %% [markdown]
# # 1. For Mas Vnr Area, median imputation is appropriate given the small amount of missing data.
#
#
#     Imputation with Median or Mean:
#
#    This is a common approach for numerical features with missing values. Using the median is often preferable as it is less sensitive to outliers.

# %%
Ames_dataset['Mas Vnr Area'].fillna(Ames_dataset['Mas Vnr Area'].median(), inplace=True)

# %% [markdown]
# # 1. Predictive Imputation
# Why Feasible:
#
# Relationship Utilization: Predictive imputation methods like k-Nearest Neighbors (k-NN) or regression models can leverage relationships between Lot Frontage and other features in the dataset.
# Accuracy: These methods can potentially provide better imputation accuracy by considering the context provided by other features.
# How to Implement:
#
# k-NN Imputation:

# %%
from sklearn.impute import KNNImputer

# Using k-NN imputer
imputer = KNNImputer(n_neighbors=5)
Ames_dataset[['Lot Frontage']] = imputer.fit_transform(Ames_dataset[['Lot Frontage']])

# %%
data=Ames_dataset.isnull().sum()
data[data>0]
# Out:
# Series([], dtype: int64)

# %%
##Exploratory data analysis
# In the case of any regression problem the first thing / code that we should run is correlation
# correlation help us figure out how our independent and output features are corelated
# If they are highly +ve or -vely corelated this means that our model prefromance will be high

# %%
# in correlation fn bydeafult correlation is pearson correlation checks relationship 
# between 2 features x and y whether they are highly +ve corelated or highly -ve corelated or 
# not corelated at all . output ranges between -1 to 1. more towards -1 h-velycorelated same for +1
# if toward zero hardly corelated at all

# %%
# here basically 2 type of corelation needs to be checked , the corelation between independent features
#and the corelation between Dependent and independent feature
# if there is high corelation between 2 independent features (+ve or -ve) then we can remove or drop any one of them bcz
# that is called multicolinearity.as we need to check for multicolinearity in linear regression
# criteria for high corelation is .88 .90+ minimum for -ve,+ve both  
# basically it is different for different different fields high corelation criteria, ex: avgrom,avgbedrom

# %% [markdown]
# numeric_columns = Ames_dataset.select_dtypes(include=['float64', 'int64'])
# correlation_matrix = numeric_columns.corr()
# print(correlation_matrix)

# %%
# One-hot encode categorical variables
Ames_dataset_encoded = pd.get_dummies(Ames_dataset ,drop_first=True)

# %%
import seaborn as sns

# %%
#Checking the relationship between dependent and independent fetures
plt.scatter(Ames_dataset['SalePrice'],Ames_dataset['Lot Area']);
plt.xlabel('SalePrice');
plt.ylabel('Lot Area');

# %%
plt.scatter(Ames_dataset['SalePrice'],Ames_dataset['Overall Qual']);
plt.xlabel('SalePrice');
plt.ylabel('Overall Qual');

# %%
plt.scatter(Ames_dataset['SalePrice'],Ames_dataset['Year Built']);
plt.xlabel('SalePrice');
plt.ylabel('Year Built');

# %%
sns.regplot(x='Year Built',y='SalePrice',data=Ames_dataset)
# Out:
# <Axes: xlabel='Year Built', ylabel='SalePrice'>

# %%
sns.regplot(x='Overall Qual',y='SalePrice',data=Ames_dataset)
# Out:
# <Axes: xlabel='Overall Qual', ylabel='SalePrice'>

# %%
sns.regplot(x='Lot Area',y='SalePrice',data=Ames_dataset)
# Out:
# <Axes: xlabel='Lot Area', ylabel='SalePrice'>

# %%
# In an dataset some sense of linearnity or an relationship must be there such as x Inc then YInc or dec and viceversa
# to create an better regression model
# For a regression model to perform well, there should ideally be a reasonably strong correlation between the predictors and the outcome variable, ensuring that the model can effectively capture the relationships in the data.

# %%
sns.regplot(x='Bedroom AbvGr',y='SalePrice',data=Ames_dataset)
# Out:
# <Axes: xlabel='Bedroom AbvGr', ylabel='SalePrice'>

# %%
#Create an Model
#creating independent and dependent features
#we have to do train , test, split
Ames_dataset_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Columns: 278 entries, Order to Sale Condition_Partial
# dtypes: bool(239), float64(11), int64(28)
# memory usage: 1.5 MB

# %% [markdown]
# ## MODEL CREATION

# %%
#Independent and dependent features 
#contain all datapoint and independent feature
#The iloc method in pandas is used to access elements, rows, and columns of a DataFrame or Series by integer-based indexing. The syntax iloc[x, y] is used to select specific data from a DataFrame, where:
X = Ames_dataset_encoded.drop('SalePrice', axis=1)
y = Ames_dataset_encoded['SalePrice']

# %%
X.head()
# Out:
#    Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0      1  526301100           20         141.0     31770             6
# 1      2  526350040           20          80.0     11622             5
# 2      3  526351010           20          81.0     14267             6
# 3      4  526353030           20          93.0     11160             7
# 4      5  527105010           60          74.0     13830             5
#
#    Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# 0             5        1960            1960         112.0  ...
# 1             6        1961            1961           0.0  ...
# 2             6        1958            1958         108.0  ...
# 3             5        1968            1968           0.0  ...
# 4             5        1997            1998           0.0  ...
#
#    Sale Type_ConLw  Sale Type_New  Sale Type_Oth  Sale Type_VWD  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
#
#    Sale Type_WD   Sale Condition_AdjLand  Sale Condition_Alloca  \
# 0           True                   False                  False
# 1           True                   False                  False
# 2           True                   False                  False
# 3           True                   False                  False
# 4           True                   False                  False
#
#    Sale Condition_Family  Sale Condition_Normal  Sale Condition_Partial
# 0                  False                   True                   False
# 1                  False                   True                   False
# 2                  False                   True                   False
# 3                  False                   True                   False
# 4                  False                   True                   False
#
# [5 rows x 277 columns]

# %%
y.head()
# Out:
# 0    215000
# 1    105000
# 2    172000
# 3    244000
# 4    189900
# Name: SalePrice, dtype: int64

# %%
#Performance matrix
#Whenever we get our dataset we should do an train test split, keeping the test dataset seperately 
# once we create our model then we will test with the test dataset to check it performance
# other then that we will use our training dataset to check model performance

# %% [markdown]
# ## TRAIN_TEST_SPLIT

# %%
#Train_Test_Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.18, random_state=22)

# %%
X_train
# Out:
#       Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 456     457  528176030           20     100.00000     14836            10
# 2719   2720  905200280           50      69.22459     13650             5
# 1463   1464  907262030           60      65.00000      8158             7
# 1913   1914  535106140           20      70.00000     10150             5
# 1933   1934  535304170           20      68.00000      7942             6
# ...     ...        ...          ...           ...       ...           ...
# 2550   2551  534429130           20      80.00000     10800             5
# 1382   1383  905107280           85      69.22459      7703             6
# 356     357  527163040           60      59.00000      7837             6
# 812     813  906226120           90      64.00000      7018             5
# 2180   2181  908154195           20     128.00000     39290            10
#
#       Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# 456              5        2004            2005         730.0  ...
# 2719             5        1958            1958           0.0  ...
# 1463             5        2003            2003         252.0  ...
# 1913             5        1958            1958           1.0  ...
# 1933             7        1953            1953           0.0  ...
# ...            ...         ...             ...           ...  ...
# 2550             7        1960            1960          88.0  ...
# 1382             8        1978            1978          40.0  ...
# 356              7        1993            1994           0.0  ...
# 812              5        1979            1979           0.0  ...
# 2180             5        2008            2009        1224.0  ...
#
#       Sale Type_ConLw  Sale Type_New  Sale Type_Oth  Sale Type_VWD  \
# 456             False          False          False          False
# 2719            False          False          False          False
# 1463            False          False          False          False
# 1913            False          False          False          False
# 1933            False          False          False          False
# ...               ...            ...            ...            ...
# 2550            False          False          False          False
# 1382            False          False          False          False
# 356             False          False          False          False
# 812             False          False          False          False
# 2180            False           True          False          False
#
#       Sale Type_WD   Sale Condition_AdjLand  Sale Condition_Alloca  \
# 456            True                   False                  False
# 2719           True                   False                  False
# 1463           True                   False                  False
# 1913          False                   False                  False
# 1933           True                   False                  False
# ...             ...                     ...                    ...
# 2550           True                   False                  False
# 1382           True                   False                  False
# 356            True                   False                  False
# 812            True                   False                   True
# 2180          False                   False                  False
#
#       Sale Condition_Family  Sale Condition_Normal  Sale Condition_Partial
# 456                   False                  False                   False
# 2719                  False                   True                   False
# 1463                  False                   True                   False
# 1913                  False                   True                   False
# 1933                  False                   True                   False
# ...                     ...                    ...                     ...
# 2550                  False                   True                   False
# 1382                  False                   True                   False
# 356                   False                   True                   False
# 812                   False                  False                   False
# 2180                  False                  False                    True
#
# [2402 rows x 277 columns]

# %%
X_test
# Out:
#       Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 1227   1228  534479150           20      63.00000      7584             5
# 373     374  527326150           20      69.22459     16635             6
# 115     116  534176060           20      78.00000      9360             6
# 978     979  923228150          160      21.00000      1533             4
# 2783   2784  907201230           80      42.00000     10385             6
# ...     ...        ...          ...           ...       ...           ...
# 304     305  911128180           50      60.00000      7500             4
# 2439   2440  528290140           60      58.00000     10852             6
# 2677   2678  903231220           50      51.00000      6120             3
# 525     526  528480040           60      85.00000     10574             8
# 225     226  905107110           90      69.22459      7424             5
#
#       Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# 1227             5        1953            1953          88.0  ...
# 373              7        1977            2000         126.0  ...
# 115              7        1972            2006           0.0  ...
# 978              6        1970            2008           0.0  ...
# 2783             6        1978            1978         123.0  ...
# ...            ...         ...             ...           ...  ...
# 304              4        1920            1950           0.0  ...
# 2439             5        2000            2000           0.0  ...
# 2677             5        1930            1950           0.0  ...
# 525              5        2005            2006           0.0  ...
# 225              5        1978            1978           0.0  ...
#
#       Sale Type_ConLw  Sale Type_New  Sale Type_Oth  Sale Type_VWD  \
# 1227            False          False          False          False
# 373             False          False          False          False
# 115             False          False          False          False
# 978             False          False          False          False
# 2783            False          False          False          False
# ...               ...            ...            ...            ...
# 304             False          False          False          False
# 2439            False          False          False          False
# 2677            False          False          False          False
# 525             False          False          False          False
# 225             False          False          False          False
#
#       Sale Type_WD   Sale Condition_AdjLand  Sale Condition_Alloca  \
# 1227           True                   False                  False
# 373            True                   False                  False
# 115            True                   False                  False
# 978            True                   False                  False
# 2783           True                   False                  False
# ...             ...                     ...                    ...
# 304           False                   False                  False
# 2439           True                   False                  False
# 2677          False                   False                  False
# 525            True                   False                  False
# 225            True                   False                  False
#
#       Sale Condition_Family  Sale Condition_Normal  Sale Condition_Partial
# 1227                  False                   True                   False
# 373                   False                   True                   False
# 115                   False                   True                   False
# 978                   False                   True                   False
# 2783                  False                   True                   False
# ...                     ...                    ...                     ...
# 304                   False                  False                   False
# 2439                  False                   True                   False
# 2677                  False                  False                   False
# 525                   False                   True                   False
# 225                   False                   True                   False
#
# [528 rows x 277 columns]

# %%
#Standard scaling / Standard scale R
#before doing model tarining , we need to do standard scale r vv imp step because as per math #intution behind linear regresiion problem, we alwways use gradient decent , our main aim in LR is to come near global minima, every independent feature unit  in our data set is calculated with respect to diff diff units .One imp step so that our conversioning of the gradient decent algorithm will take faster  
# we have to normalize or standard all the datapoints to the same scale that should be based on standardize scaler
#REason for standardization of dataset:	we alwways use gradient decent , our main aim in LR is to come near global minima, every independent feature unit  in our data set should be in same scale , beacuse of that the conversion will happen quickly.

# %% [markdown]
# ## STANDARDIZING THE DATASET

# %%
#STnadard the dataset
#scaler will conatin the object
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
 X_train=scaler.fit_transform(X_train)
print(Ames_dataset_encoded.dtypes)
# Out:
# Order                       int64
# PID                         int64
# MS SubClass                 int64
# Lot Frontage              float64
# Lot Area                    int64
#                            ...
# Sale Condition_AdjLand       bool
# Sale Condition_Alloca        bool
# Sale Condition_Family        bool
# Sale Condition_Normal        bool
# Sale Condition_Partial       bool
# Length: 278, dtype: object

# %%
X_test=scaler.transform(X_test)

# %%
#learn lr model

# %% [markdown]
# # MODEL TRAINING

# %%
# whENEVER WE solve regression problem 2 imp things will be there 1. coefficients 2. Intercept

# %%
from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
regression= LinearRegression()

# regression=LinearRegression() This line creates an instance of the LinearRegression class and assigns it to the variable regression. This instance represents a linear regression model, which is used to predict a continuous target variable based on one or more input features. regression.fit(X_train, y_train):

# %%
regression.fit(X_train,y_train)

# This line trains the linear regression model using the training data. X_train is a 2D array or DataFrame containing the input features, and y_train is a 1D array or Series containing the target variable. The fit method calculates the best-fit line (or hyperplane in the case of multiple features) that minimizes the error between the predicted and actual target values.
# Out:
# LinearRegression()

# %%
regression.coef_
# no of coef= no of independent features, 
# bcz for every independnt feature there will be an coefficient 
# IT indicate an unit increase in 1st independt feature will affect 8.49221760e-01 the target variable means the TV will incrasee at this rate
# Out:
# array([ 1.16867849e+03,  1.37461018e+03, -2.51532130e+03,  1.03262769e+03,
#         5.46361495e+03,  9.03172849e+03,  6.94966798e+03,  1.05347737e+04,
#         1.56190097e+03,  5.34398775e+03, -1.13397102e+15, -4.23292413e+14,
#        -1.07701114e+15,  1.08794904e+15, -7.14049487e+15, -7.70983096e+15,
#        -8.85350195e+14,  9.16321753e+15,  7.53019738e+02, -2.53257536e+02,
#         1.62531576e+03,  7.99352615e+02, -3.86592638e+03, -3.22470250e+03,
#         8.86927271e+02,  3.59534360e+03,  3.24027813e+04,  2.49972538e+03,
#         2.41734013e+03,  6.84995783e+02,  1.84112098e+02,  3.36138810e+02,
#        -1.20392672e+02,  2.53850000e+03, -5.87125000e+02,  1.97000000e+02,
#        -6.43125000e+01,  7.82500000e+01,  7.32956250e+03,  1.92114375e+04,
#         2.36050000e+03,  8.78396875e+03,  3.74305000e+04,  2.93232500e+04,
#         2.09493750e+03, -2.68500000e+02, -2.04500000e+02,  4.77750000e+02,
#        -5.24250000e+02,  5.20687500e+02,  5.56125000e+02, -1.22475000e+03,
#         9.57500000e+01, -3.78093750e+02,  1.75250000e+02,  1.25050000e+03,
#        -4.83125000e+02, -8.50000000e+01,  2.53250000e+02,  1.02837500e+03,
#        -2.49706250e+03,  7.90375000e+02,  1.08437500e+03,  4.77500000e+01,
#        -1.60281250e+03, -3.02475000e+03,  9.39500000e+02, -3.69825000e+03,
#        -2.43087500e+03,  4.54375000e+02,  2.91950000e+03, -9.17500000e+02,
#        -1.86375000e+02, -7.96250000e+01, -3.56375000e+03, -3.84650000e+03,
#         1.50600000e+03, -2.81866406e+03,  3.85650000e+03,  3.19418750e+03,
#        -2.44275000e+03, -1.26450000e+03, -1.56187500e+03, -1.69959180e+03,
#         1.23000000e+03,  4.16087500e+03, -2.00350000e+03, -1.19612500e+03,
#         1.26162500e+03,  4.81125000e+03,  1.61287500e+03,  1.95325000e+03,
#        -6.87343750e+01,  1.13587500e+03,  4.14218750e+02,  1.75968750e+02,
#        -5.93468750e+02,  9.86562500e+01,  2.11809375e+03, -6.33125000e+02,
#        -1.29100000e+03, -3.30647712e+13,  3.23000000e+02, -4.78250000e+02,
#        -2.52350000e+03, -3.40737500e+03, -3.19320312e+03,  5.48500000e+02,
#         2.80537500e+03, -9.92375000e+02, -4.31812500e+02, -3.27250000e+02,
#         1.08625000e+03,  1.05871875e+03,  1.84362500e+03,  5.71562500e+01,
#         1.57450000e+03, -3.56812500e+02,  1.88975000e+03,  9.27126875e+04,
#         1.65596250e+04,  2.84075355e+13,  1.50617500e+04,  6.87331875e+04,
#         4.26101250e+04,  3.96272188e+04, -6.53916928e+13,  8.62500000e+01,
#         3.07368750e+03,  1.82575000e+03, -1.68850000e+03, -1.66775000e+03,
#        -3.79453125e+02,  1.42887500e+03, -8.49375000e+02, -2.16632752e+15,
#        -3.40000000e+01,  7.07294922e+01, -3.25200000e+03, -1.12562500e+02,
#        -6.61500000e+02,  1.91125000e+02, -3.76125000e+02, -9.76000000e+02,
#         2.79750000e+02,  2.18900000e+03,  3.54226562e+02,  4.30125000e+02,
#        -1.09875000e+03, -2.80375000e+02, -2.27125000e+02,  2.16632752e+15,
#        -1.06975000e+03,  1.15625000e+02,  3.39600000e+03, -5.13656250e+02,
#         2.66906250e+02,  1.78400000e+03, -2.16687500e+03,  5.18950000e+03,
#         3.52712500e+03, -1.25700000e+03, -1.11370000e+04, -1.14264531e+04,
#         1.09929688e+02,  9.83750000e+02,  1.42531250e+02,  1.81337500e+03,
#        -8.39375000e+02,  1.51750000e+02, -5.98406250e+02,  8.26562500e+02,
#        -7.26125000e+02, -2.19193750e+03, -8.79909375e+03,  4.98237304e+15,
#        -1.03675781e+02, -7.33075000e+03,  1.53368750e+03,  1.92018750e+03,
#        -6.62729274e+15,  9.01500000e+02,  2.62843750e+03,  3.51693750e+03,
#        -1.53462500e+03, -2.68565625e+03, -1.03278125e+03, -1.96500000e+02,
#         1.70331250e+03, -6.38375000e+02,  1.64491969e+15, -9.56500000e+02,
#         1.41100000e+03, -1.69550000e+03,  2.47750000e+02, -2.02518750e+03,
#        -5.53453125e+03, -1.80437500e+03, -2.58940625e+03,  9.19312500e+02,
#         5.42750000e+02,  1.70750000e+02, -5.40125000e+02,  1.27862500e+03,
#        -9.85437500e+02, -5.80812500e+02, -2.13218750e+02, -1.24606250e+03,
#        -9.17875000e+02, -1.05375000e+02,  1.34500000e+02,  2.99000000e+02,
#         2.12500000e+00, -2.91775000e+03, -9.00450000e+03,  5.47250000e+02,
#        -8.95100000e+03, -4.71875000e+00,  1.77311719e+03,  1.52587500e+03,
#        -3.65000000e+01,  3.51750000e+02, -6.39097656e+02,  4.96675000e+03,
#        -5.07421875e+02,  2.22000000e+02,  2.41162500e+03,  1.75187500e+02,
#        -7.06875000e+02,  3.35650000e+03,  8.91875000e+02,  2.41128125e+03,
#         2.95875000e+02,  3.42378516e+03,  4.75631250e+03, -1.42342594e+14,
#        -1.78100000e+03, -3.50500000e+02, -1.62938750e+04, -6.64301562e+03,
#        -1.96189494e+14, -3.97300000e+03, -2.55000000e+04,  9.43750000e+03,
#         3.53775000e+03,  3.38532088e+14,  4.32906250e+03,  1.74726250e+04,
#        -3.01875000e+02, -4.41375000e+02, -1.28093750e+03, -1.28800000e+03,
#        -6.45525000e+03, -2.80950000e+03,  1.25656250e+03,  2.15725000e+03,
#        -8.14375000e+01,  1.79375000e+03,  2.04967500e+04,  1.11006570e+05,
#         2.15068750e+04,  1.06332875e+05,  1.05073750e+04,  9.32875000e+02,
#         1.69587500e+03,  8.87625000e+02,  2.13625000e+02,  3.86250000e+02,
#         7.31506250e+03,  2.30000000e+02, -8.10000000e+01,  7.11625000e+02,
#         9.48250000e+02,  1.19262500e+03,  2.31750000e+02,  3.17050000e+03,
#        -1.58212500e+03])

# %%
print(regression.intercept_)
# Out:
# 182002.82197775596

# %%
# On which parameters the model is trained
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
### Predcition with test data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([ 9.25890626e+04,  2.20160056e+05,  1.73783149e+05,  9.29203680e+04,
#         1.75154102e+05,  2.31728524e+05,  1.42219102e+05,  2.26954931e+05,
#         1.29589957e+05,  1.73673761e+05,  3.35204274e+05,  1.88577181e+05,
#         1.94725254e+05,  4.79447181e+05,  2.03722806e+05,  1.50746973e+05,
#         1.08716953e+05,  1.89581884e+05,  1.48850906e+05,  1.00142453e+05,
#         1.50146446e+05,  8.67991336e+04,  1.62776628e+05,  2.01143712e+05,
#         1.06179587e+05,  1.03781821e+05,  6.82910782e+04,  4.50654877e+05,
#         1.25102899e+05,  1.37399587e+05,  1.21105774e+05,  2.14210259e+05,
#         1.19092009e+05,  1.69774524e+05,  1.45726958e+05,  3.12968009e+05,
#         7.54845086e+04,  1.55733993e+05,  1.95250859e+05,  7.59676105e+04,
#         3.55359096e+05,  8.99458055e+04,  2.50139431e+05,  1.97867634e+05,
#         2.93464393e+05,  2.31992767e+05,  8.85502085e+04,  2.45694806e+05,
#         2.93124634e+05,  1.29724431e+05,  1.50227779e+05,  1.35877539e+05,
#         1.50663821e+05,  1.98509737e+05,  4.02870978e+05,  1.14261684e+05,
#         1.54635477e+05,  1.49876118e+05,  1.65476750e+05,  9.06051417e+04,
#         3.23354112e+05,  1.24668739e+05,  2.36498977e+05,  1.30634612e+05,
#         2.13761939e+05,  1.81013611e+05,  2.28685759e+05,  1.71988485e+05,
#         1.23517063e+05,  2.28201071e+05,  1.37881719e+05,  1.16408313e+05,
#         7.27580746e+04,  2.43682134e+05,  2.27354768e+05,  3.33735727e+05,
#         2.78562040e+05,  1.95331426e+05,  2.55908909e+05,  2.04833618e+05,
#         1.45240102e+05,  3.24745252e+05,  1.11919105e+05,  2.09175487e+05,
#         2.34746399e+05,  2.43621274e+05,  5.45077143e+04,  2.06051493e+05,
#         1.56938759e+05,  4.30760618e+05,  1.59197384e+05,  1.43869977e+05,
#         2.10394721e+05,  2.63942915e+05,  3.53255659e+05,  2.57013368e+05,
#         1.84615727e+05,  1.92035227e+05,  1.39894024e+05,  1.42739078e+05,
#         2.31982299e+05,  2.20874759e+05,  1.12058118e+05,  1.37328368e+05,
#         1.43107932e+05,  1.90963734e+05,  1.05359899e+05,  1.54578790e+05,
#         4.96667284e+05,  1.42094821e+05,  3.04644534e+05,  1.13917899e+05,
#         1.90095665e+05,  1.61627227e+05,  1.35409324e+05,  2.30171159e+05,
#         1.55308290e+05,  1.19885232e+05,  1.24667250e+05,  1.47966921e+05,
#         6.28446252e+05,  2.34951040e+05,  1.72924259e+05,  2.37053098e+05,
#         1.14331545e+05,  1.36391977e+05,  1.71937634e+05,  1.56959134e+05,
#         2.72548977e+05,  3.29653096e+05,  1.52375519e+05,  1.95526445e+05,
#         1.55332071e+05,  2.01414331e+05,  2.18474977e+05,  1.53824681e+05,
#         2.32096091e+05,  2.08637977e+05,  1.28630321e+05,  1.10072368e+05,
#         5.68010990e+04,  1.59951540e+05,  1.26667286e+05,  7.98035323e+04,
#         1.59704071e+05,  1.64559602e+05,  1.30293298e+05,  2.43166049e+05,
#         1.41431915e+05,  1.40929321e+05,  1.01797041e+05,  1.40775243e+05,
#         1.41600813e+05,  1.36925806e+05,  1.54204321e+05,  2.26472290e+05,
#         1.87755274e+05,  1.60401868e+05,  1.95397384e+05,  1.30061504e+05,
#         1.79392649e+05,  1.14650454e+05,  2.91298384e+05,  1.50241939e+05,
#         2.14353081e+05,  1.40194759e+05,  2.26616477e+05,  1.31675985e+05,
#         1.05786837e+05,  1.39183828e+05,  1.39240234e+05,  2.09687396e+05,
#         2.23131665e+05,  1.57469993e+05,  2.37430946e+05,  2.08669368e+05,
#         2.11506243e+05,  1.54808721e+05,  5.28161180e+04,  1.73868040e+05,
#         3.65677143e+04,  1.28390149e+05,  1.49554024e+05,  1.31316931e+05,
#         1.15438032e+05,  1.60931391e+05,  1.73774149e+05,  1.41070618e+05,
#         1.65520724e+05,  1.56974212e+05,  1.16372734e+05,  1.54252673e+05,
#         1.16373969e+05,  9.64392143e+04,  2.14397931e+05,  1.71715134e+05,
#         1.50417515e+05,  2.13336086e+05,  1.51636188e+05,  1.16132243e+05,
#         1.89831368e+05,  1.42435665e+05,  3.99300040e+05,  1.96337384e+05,
#         1.56200571e+05,  1.35830040e+05,  2.99678227e+05,  1.28465696e+05,
#         2.16526862e+05,  2.02912790e+05,  2.76781649e+04,  1.35748176e+05,
#         1.46915158e+05,  1.64715909e+05,  1.75814102e+05,  1.06173946e+05,
#         1.37115594e+05,  2.13890634e+05,  1.65270759e+05,  1.79128790e+05,
#         2.07713915e+05,  2.23094884e+05,  2.24149790e+05,  2.78716884e+05,
#         1.59146605e+05,  1.25381165e+05,  1.71718212e+05,  1.20139290e+05,
#         1.16020767e+05,  1.36772170e+05,  1.22660688e+05,  3.39359602e+05,
#         1.27600114e+05,  2.12010571e+05,  1.10999857e+05,  1.16795846e+05,
#         1.93881024e+05,  1.22303828e+05,  1.72716946e+05,  3.14260424e+05,
#         2.44645134e+05,  2.07800868e+05,  1.50115446e+05,  2.49622946e+05,
#         2.23595415e+05,  9.02513836e+04,  2.02020727e+05,  8.46000469e+04,
#         1.17734337e+05,  6.92531859e+04,  2.62494170e+05,  1.26437368e+05,
#         9.14159002e+04,  2.91868009e+05,  3.55519877e+05,  1.67307736e+05,
#         3.06884237e+05,  1.65238060e+05,  1.59794359e+05,  2.38724821e+05,
#         3.00362134e+05,  1.40089149e+05,  1.30322664e+05,  1.60336820e+05,
#         2.29304196e+05,  1.49011219e+05,  1.94311516e+05,  1.35613567e+05,
#        -6.53916927e+13,  1.13112181e+05,  2.00274134e+05,  1.38888290e+05,
#         2.16428166e+05,  2.18696931e+05,  1.03136686e+05,  2.13696509e+05,
#         1.07573724e+05,  1.71973056e+05,  9.42675862e+04,  1.11103164e+05,
#         1.23743352e+05,  1.87671660e+05,  1.09656379e+05, -3.30647710e+13,
#         2.00890471e+05,  1.34885263e+05,  2.61451931e+05,  1.57187602e+05,
#         1.38894214e+05,  2.32695636e+05,  1.32109165e+05,  7.45241986e+04,
#         1.72983462e+05,  1.27913727e+05,  1.17933618e+05,  1.63597859e+05,
#         8.63029768e+04,  2.31052206e+05,  2.29067659e+05,  7.37652899e+04,
#         1.15799337e+05,  2.15896227e+05,  1.16414270e+05, -6.53916928e+13,
#         1.81238024e+05,  1.27075984e+05,  1.52929759e+05,  1.31892438e+05,
#         1.83417529e+05,  4.63792643e+05,  2.05868565e+05,  2.26884752e+05,
#         1.27131321e+05,  1.08746509e+05,  1.29148602e+05,  3.60381743e+05,
#         2.16474148e+05,  2.94493134e+05,  6.78698680e+04,  1.09431000e+05,
#         2.30515009e+05,  1.69780534e+05,  3.68790524e+05,  2.55390471e+05,
#         2.04256150e+05,  1.78746634e+05,  2.04457674e+05,  1.35257355e+05,
#         2.51194804e+05,  1.96520789e+05,  1.91110368e+05,  3.10910915e+05,
#         1.99691587e+05,  1.33111006e+05,  2.04227556e+05,  1.82257634e+05,
#         1.13311170e+05,  1.65713384e+05,  1.42859771e+05,  1.79227009e+05,
#         6.69967143e+04,  2.21196243e+05,  2.25929477e+05,  1.92762837e+05,
#         1.67936132e+05,  1.62671321e+05,  2.70280915e+05,  1.61670143e+05,
#         1.51480714e+05,  2.54096071e+05,  1.42889650e+05,  1.06330438e+05,
#         1.76950993e+05,  3.65685977e+05,  1.72754237e+05,  1.71882227e+05,
#         1.42775384e+05,  1.47308868e+05,  1.07115602e+05,  1.93497763e+05,
#         1.41791213e+05,  1.05280714e+05,  7.84143080e+04,  1.29463716e+05,
#         3.05843540e+05,  1.49423402e+05,  1.45140466e+05,  2.35761259e+05,
#         1.55609615e+05,  2.31263900e+05,  2.06459134e+05,  2.81152165e+05,
#         1.45494290e+05,  1.32405415e+05,  1.32979071e+05,  1.70359994e+05,
#         1.04110728e+05,  1.31168962e+05,  2.74199571e+05,  2.03469649e+05,
#         1.57314752e+05,  1.92741384e+05,  2.22561602e+05,  1.54231339e+05,
#         1.84481837e+05,  1.44528563e+05,  3.58058533e+04,  1.52123087e+05,
#         2.70488924e+05,  1.16051096e+05,  1.85423322e+05,  1.30290004e+05,
#         1.08224226e+05,  1.42959536e+05,  1.27930218e+05,  1.54055742e+05,
#         1.73377352e+05,  2.19839384e+05,  1.23445009e+05,  7.78758680e+04,
#         1.44725349e+05,  1.08260259e+05,  1.07420119e+05,  1.29491977e+05,
#         1.20208170e+05,  2.62548040e+05,  1.90239821e+05,  1.35908759e+05,
#         1.48089024e+05,  5.89283524e+04,  3.98374274e+05,  1.93819487e+05,
#         1.12529618e+05,  2.03535734e+05,  1.34672196e+05,  1.23925899e+05,
#         2.64971759e+05,  1.37855931e+05,  1.63145513e+05,  1.15990886e+05,
#         1.15395355e+05,  1.52353415e+05,  2.19291102e+05,  1.09047790e+05,
#         1.38159723e+05,  1.87273570e+05,  2.60866899e+05,  1.31011184e+05,
#         1.02594962e+05,  1.15383454e+05,  8.52896953e+04,  1.12321864e+05,
#         2.03283487e+05,  1.69040149e+05,  1.83276156e+05,  1.52901974e+05,
#         3.21571134e+05,  1.41636775e+05,  2.32817915e+05,  1.18860685e+05,
#         1.60424681e+05,  1.24988188e+05,  3.40360909e+05,  2.67995009e+05,
#         1.54934946e+05,  1.54764384e+05,  3.48301165e+05,  1.52852540e+05,
#         1.36550406e+05,  2.21323352e+05,  3.58583268e+05,  1.50069318e+05,
#         7.04712682e+04,  1.49302625e+05,  1.33497564e+05,  1.22281556e+05,
#         1.05744917e+05,  2.89572618e+05,  1.09179312e+05,  3.93853649e+05,
#         1.38170384e+05,  1.66961836e+05,  1.56346946e+05,  3.71051946e+05,
#         1.69776399e+05,  1.00241277e+05,  1.34764977e+05,  1.09364368e+05,
#         9.15578680e+04,  3.27309581e+05,  1.23408879e+05,  1.57229290e+05,
#         3.25815315e+05,  1.46965714e+05,  1.42307946e+05,  2.12470571e+05,
#         2.84075349e+13,  9.70244461e+04,  1.09823259e+05,  1.06102681e+05,
#         1.53031368e+05,  3.09237243e+05,  1.50009774e+05,  1.44699618e+05,
#         1.14372024e+05,  1.46725063e+05,  7.05858680e+04,  2.33222362e+05,
#         1.20994018e+05,  1.72169524e+05,  1.68300196e+05,  2.35379790e+05,
#         2.00782931e+05,  1.84389993e+05,  1.47330602e+05,  1.60425770e+05,
#         3.12987284e+05,  1.81283681e+05,  2.09829502e+05,  2.46530491e+05,
#         1.09789010e+05,  1.76777125e+05,  1.46321444e+05,  1.96401196e+05,
#         9.59416649e+04,  3.38620212e+05,  1.82454759e+05,  2.37070315e+05,
#         3.06462071e+05,  1.40100821e+05,  2.07962313e+05,  1.48355118e+05,
#         1.59747118e+05,  9.43227057e+04,  1.29720199e+05,  2.49307071e+05,
#         1.04764420e+05,  9.67812586e+04,  2.50922727e+05,  4.57841462e+05,
#         1.09687602e+05,  1.33992795e+05,  9.95306137e+04,  7.25419116e+04,
#         1.96278790e+05,  8.68221180e+04,  2.44478289e+05,  1.69567086e+05])

# %%
## plot an scatter plot for prediction
plt.scatter(y_test,reg_pred)
